# %%
########### Import libraries ###########
import requests
#beautifulsoup用於解析html或xml等標籤語言的文檔
import pandas
import unicode
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-c4c3848512f5> in <module>()
#       3 #beautifulsoup用於解析html或xml等標籤語言的文檔
#       4 import pandas
# ----> 5 import unicode
#       6 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'unicode'

# %%
#爬出股市資料網的table info : list
def indicatortable_crawler():
    url = 'http://goodinfo.tw/StockInfo/index.asp'
    headers = {"User-Agent":"Mozilla/5.0 (Linux; Android 5.0; SM-G900P Build/LRX21T) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Mobile Safari/537.36",
                "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"}
    html = requests.get(url,headers = headers)
    html.encoding = 'utf8'
    soup = BeautifulSoup(''.join(html.text),"html.parser")
    table_list = soup.findAll('table',{'class':'none_tbl'})
    return table_list

# %%
table_list = indicatortable_crawler()

# %%
def getNews():
    news_list = []
    table_list = indicatortable_crawler()
    #取出
    for news in table_list[4].findAll("tr"):
        try:
            newsInfo = {}
            #get news classification & title(with link)
            newsInfo['newsclass'] = news.find("nobr").text.replace('\xa0',' ')
            newsInfo['newstitle'] = news.findAll("a")[1].text
            newsInfo['newslink'] = news.findAll("a")[1]["href"][18:].replace("%3A",":").replace("%2F","/").replace("%2E",".").replace("%3F","?").replace("%3D","=")
            newsInfo['newsdate'] = news.find("span").text.replace('\xa0',' ')
            news_list.append(newsInfo)
            print(newsInfo)
        except:
            print('exception occur')
    return news_list[:10]
getNews()
# Out:
# {'newsclass': '2384 勝華科技', 'newstitle': '金融監督管理委員會已核准展延重編103年第三季,103年度,104年第一季,第二季,104年度,105年第二季,105年度合併財務報告公告申報期限。', 'newslink': 'l.asp?STOCK_ID=2384&CLAIM_TIME=2017/06/07+13:17:42', 'newsdate': '  (公告訊息 06/07 13:17)'}
# exception occur
# {'newsclass': '6239 力成', 'newstitle': '力成受邀參加瑞銀證劵於台北舉辦之法人說明會', 'newslink': 'l.asp?STOCK_ID=6239&CLAIM_TIME=2017/06/07+12:55:11', 'newsdate': '  (公告訊息 06/07 12:55)'}
# {'newsclass': '6239 力成', 'newstitle': '力成受邀參加元大金控於台北舉辦之法人說明會', 'newslink': 'l.asp?STOCK_ID=6239&CLAIM_TIME=2017/06/07+12:54:51', 'newsdate': '  (公告訊息 06/07 12:54)'}
# {'newsclass': '財經新聞', 'newstitle': '「蘋果產品變醜」？\u3000網嘆：沒有賈伯斯的蘋果只剩空殼', 'newslink': 'http://www.ettoday.net/news/20170607/939753.htm?from=rss', 'newsdate': '  (ETtoday東森新聞雲 06/07 12:18)'}
# {'newsclass': '8497 聯廣', 'newstitle': '董事會決議股息分派基準日相關事宜', 'newslink': 'l.asp?STOCK_ID=8497&CLAIM_TIME=2017/06/07+12:15:36', 'newsdate': '  (公告訊息 06/07 12:15)'}
# {'newsclass': '1516 川飛', 'newstitle': '106年股東常會重要決議事項。', 'newslink': 'l.asp?STOCK_ID=1516&CLAIM_TIME=2017/06/07+12:06:32', 'newsdate': '  (公告訊息 06/07 12:06)'}
# {'newsclass': '6207 雷科', 'newstitle': '雷科105年度股利分派經106年6月7日股東會決議有所變動', 'newslink': 'l.asp?STOCK_ID=6207&CLAIM_TIME=2017/06/07+12:03:15', 'newsdate': '  (公告訊息 06/07 12:03)'}
# {'newsclass': '1408 中興紡織', 'newstitle': '澄清媒體有關中興紡織董事長之報導內容', 'newslink': 'l.asp?STOCK_ID=1408&CLAIM_TIME=2017/06/07+12:01:04', 'newsdate': '  (公告訊息 06/07 12:01)'}
# {'newsclass': '4974 亞泰', 'newstitle': '亞泰一０六年股東常會重要決議事項', 'newslink': 'l.asp?STOCK_ID=4974&CLAIM_TIME=2017/06/07+11:58:51', 'newsdate': '  (公告訊息 06/07 11:58)'}
# [{'newsclass': '2384 勝華科技',
#   'newsdate': '  (公告訊息 06/07 13:17)',
#   'newslink': 'l.asp?STOCK_ID=2384&CLAIM_TIME=2017/06/07+13:17:42',
#   'newstitle': '金融監督管理委員會已核准展延重編103年第三季,103年度,104年第一季,第二季,104年度,105年第二季,105年度合併財務報告公告申報期限。'},
#  {'newsclass': '6239 力成',
#   'newsdate': '  (公告訊息 06/07 12:55)',
#   'newslink': 'l.asp?STOCK_ID=6239&CLAIM_TIME=2017/06/07+12:55:11',
#   'newstitle': '力成受邀參加瑞銀證劵於台北舉辦之法人說明會'},
#  {'newsclass': '6239 力成',
#   'newsdate': '  (公告訊息 06/07 12:54)',
#   'newslink': 'l.asp?STOCK_ID=6239&CLAIM_TIME=2017/06/07+12:54:51',
#   'newstitle': '力成受邀參加元大金控於台北舉辦之法人說明會'},
#  {'newsclass': '財經新聞',
#   'newsdate': '  (ETtoday東森新聞雲 06/07 12:18)',
#   'newslink': 'http://www.ettoday.net/news/20170607/939753.htm?from=rss',
#   'newstitle': '「蘋果產品變醜」？\u3000網嘆：沒有賈伯斯的蘋果只剩空殼'},
#  {'newsclass': '8497 聯廣',
#   'newsdate': '  (公告訊息 06/07 12:15)',
#   'newslink': 'l.asp?STOCK_ID=8497&CLAIM_TIME=2017/06/07+12:15:36',
#   'newstitle': '董事會決議股息分派基準日相關事宜'},
#  {'newsclass': '1516 川飛',
#   'newsdate': '  (公告訊息 06/07 12:06)',
#   'newslink': 'l.asp?STOCK_ID=1516&CLAIM_TIME=2017/06/07+12:06:32',
#   'newstitle': '106年股東常會重要決議事項。'},
#  {'newsclass': '6207 雷科',
#   'newsdate': '  (公告訊息 06/07 12:03)',
#   'newslink': 'l.asp?STOCK_ID=6207&CLAIM_TIME=2017/06/07+12:03:15',
#   'newstitle': '雷科105年度股利分派經106年6月7日股東會決議有所變動'},
#  {'newsclass': '1408 中興紡織',
#   'newsdate': '  (公告訊息 06/07 12:01)',
#   'newslink': 'l.asp?STOCK_ID=1408&CLAIM_TIME=2017/06/07+12:01:04',
#   'newstitle': '澄清媒體有關中興紡織董事長之報導內容'},
#  {'newsclass': '4974 亞泰',
#   'newsdate': '  (公告訊息 06/07 11:58)',
#   'newslink': 'l.asp?STOCK_ID=4974&CLAIM_TIME=2017/06/07+11:58:51',
#   'newstitle': '亞泰一０六年股東常會重要決議事項'}]

# %%
def getStcokPrizeTop10():
    main_list = []
    table_list = indicatortable_crawler()
    #取出
    for company in table_list[13].findAll("tr"):
        list_companyInfo = []
        companyInfo = company.findAll("nobr")
        for index in range(0,len(companyInfo)):
            if index>1:
                list_companyInfo.append(companyInfo[index].text[1:])
            else:
                list_companyInfo.append(companyInfo[index].text)
        main_list.append(list_companyInfo)
        print("company : "+str(list_companyInfo))
    return main_list
getStcokPrizeTop10()
# Out:
# company : ['3008', '大立光', '4790', '-60', '-1.2', '224', '1']
# company : ['6510', '精測', '1450', '+40', '+2.8', '974', '2']
# company : ['5274', '信驊', '638', '-12', '-1.8', '273', '3']
# company : ['1565', '精華', '595', '+5', '+0.8', '314', '4']
# company : ['6415', '矽力-KY', '580', '-6', '-1', '158', '5']
# company : ['6409', '旭隼', '494', '+3', '+0.6', '133', '6']
# company : ['6452', '康友-KY', '475', '+2.5', '+0.5', '426', '7']
# company : ['2059', '川湖', '444', '+6', '+1.4', '173', '8']
# company : ['5904', '寶雅', '407', '-13', '-3.1', '97', '9']
# company : ['6414', '樺漢', '394.5', '-3.5', '-0.9', '1050', '10']
# company : ['3529', '力旺', '393', '+4', '+1', '91', '11']
# company : ['2207', '和泰車', '386.5', '-3.5', '-0.9', '284', '12']
# company : ['6548', '長華科', '381', '-5', '-1.3', '41', '13']
# company : ['2231', '為升', '368', '+9.5', '+2.6', '1171', '14']
# company : ['4966', '譜瑞-KY', '364', '0', '0', '872', '15']
# company : ['3081', '聯亞', '355', '+7', '+2', '1964', '16']
# company : ['2474', '可成', '354', '+15', '+4.4', '13028', '17']
# company : ['2723', '美食-KY', '345', '+5', '+1.5', '409', '18']
# company : ['8299', '群聯', '341', '-9', '-2.6', '2552', '19']
# company : ['1590', '亞德客-KY', '335.5', '-11.5', '-3.3', '799', '20']
# company : ['3152', '璟德', '332', '-13.5', '-3.9', '592', '21']
# company : ['910708', '恒大健-DR', '332', '0', '0', '0', '22']
# company : ['5269', '祥碩', '330', '-0.5', '-0.2', '1267', '23']
# company : ['1476', '儒鴻', '324', '-1', '-0.3', '435', '24']
# company : ['8464', '億豐', '316.5', '+6', '+1.9', '644', '25']
# company : ['2227', '裕日車', '304', '-2', '-0.6', '485', '26']
# company : ['3406', '玉晶光', '292', '-6', '-2', '3240', '27']
# company : ['2357', '華碩', '289', '-2.5', '-0.9', '806', '28']
# company : ['3691', '碩禾', '286.5', '+0.5', '+0.2', '1042', '29']
# company : ['2912', '統一超', '272', '-3', '-1.1', '838', '30']
# company : ['5287', '數字', '268.5', '-2.5', '-0.9', '106', '31']
# company : ['4174', '浩鼎', '262.5', '-3.5', '-1.3', '367', '32']
# company : ['2729', '瓦城', '258', '0', '0', '21', '33']
# company : ['2496', '卓越', '256', '+10', '+4.1', '497', '34']
# company : ['8044', '網家', '255.5', '+6', '+2.4', '1244', '35']
# company : ['1264', '德麥', '251', '+2', '+0.8', '41', '36']
# company : ['2395', '研華', '249', '+0.5', '+0.2', '263', '37']
# company : ['6569', '醫揚', '248', '+2', '+0.8', '42', '38']
# company : ['6488', '環球晶', '246', '-11', '-4.3', '4206', '39']
# company : ['2454', '聯發科', '245', '+2', '+0.8', '10042', '40']
# company : ['8406', '金可-KY', '244', '-1', '-0.4', '276', '41']
# company : ['6111', '大宇資', '238', '-3.5', '-1.4', '697', '42']
# company : ['3611', '鼎翰', '235.5', '-1.5', '-0.6', '49', '43']
# company : ['6456', 'GIS-KY', '235', '+5', '+2.2', '6287', '44']
# company : ['3665', '貿聯-KY', '227', '-5', '-2.2', '8686', '45']
# company : ['4947', '昂寶-KY', '221.5', '+2', '+0.9', '751', '46']
# company : ['8454', '富邦媒', '217', '+1.5', '+0.7', '182', '47']
# company : ['2727', '王品', '213.5', '-0.5', '-0.2', '588', '48']
# company : ['2330', '台積電', '210.5', '-1.5', '-0.7', '15382', '49']
# company : ['3131', '弘塑', '210', '+5.5', '+2.7', '2062', '50']
# company : ['2049', '上銀', '207', '-3', '-1.4', '1254', '51']
# company : ['6426', '統新', '207', '-5', '-2.4', '1300', '52']
# company : ['3293', '鈊象', '206', '-5', '-2.4', '807', '53']
# company : ['5903', '全家', '206', '+0.5', '+0.2', '4', '54']
# company : ['4162', '智擎', '203', '-1.5', '-0.7', '469', '55']
# company : ['6462', '神盾', '200.5', '+8', '+4.2', '3102', '56']
# company : ['5263', '智崴', '196.5', '-3.5', '-1.8', '195', '57']
# company : ['1707', '葡萄王', '190', '+0.5', '+0.3', '227', '58']
# company : ['9951', '皇田', '189', '-1', '-0.5', '145', '59']
# company : ['4147', '中裕', '186', '-1', '-0.5', '503', '60']
# company : ['3552', '同致', '185.5', '-5.5', '-2.9', '2026', '61']
# company : ['6238', '勝麗', '185', '-1', '-0.5', '607', '62']
# company : ['8422', '可寧衛', '183', '+1.5', '+0.8', '251', '63']
# company : ['2439', '美律', '181.5', '-2.5', '-1.4', '4688', '64']
# company : ['6523', '達爾膚', '179.5', '-3.5', '-1.9', '41', '65']
# company : ['6279', '胡連', '178.5', '-3', '-1.6', '1401', '66']
# company : ['3413', '京鼎', '177.5', '+2.5', '+1.4', '1954', '67']
# company : ['8437', '大地-KY', '177.5', '+0.5', '+0.3', '10', '68']
# company : ['6803', '崑鼎', '176.5', '+1', '+0.6', '27', '69']
# company : ['6568', '宏觀', '176', '+1.5', '+0.9', '216', '70']
# company : ['4763', '材料-KY', '175.5', '0', '0', '191', '71']
# company : ['9921', '巨大', '175.5', '-1.5', '-0.8', '533', '72']
# company : ['8444', '綠河-KY', '175', '+1', '+0.6', '35', '73']
# company : ['8436', '大江', '174.5', '+4.5', '+2.6', '1472', '74']
# company : ['2239', '英利-KY', '174', '+5', '+3', '389', '75']
# company : ['5536', '聖暉', '172.5', '-3', '-1.7', '680', '76']
# company : ['8341', '日友', '170.5', '+4.5', '+2.7', '1072', '77']
# company : ['8114', '振樺電', '169.5', '-1', '-0.6', '85', '78']
# company : ['4912', '聯德控股-KY', '169', '+1', '+0.6', '947', '79']
# company : ['4438', '廣越', '168', '-2.5', '-1.5', '148', '80']
# company : ['1580', '新麥', '167', '-0.5', '-0.3', '93', '81']
# company : ['2308', '台達電', '166', '-3.5', '-2.1', '11608', '82']
# company : ['6146', '耕興', '162.5', '-1.5', '-0.9', '47', '83']
# company : ['2926', '誠品生', '162', '-1', '-0.6', '39', '84']
# company : ['3130', '一零四', '162', '+1', '+0.6', '11', '85']
# company : ['9914', '美利達', '160', '-0.5', '-0.3', '237', '86']
# company : ['8083', '瑞穎', '159.5', '-3', '-1.8', '235', '87']
# company : ['3541', '西柏', '158.5', '0', '0', '58', '88']
# company : ['1537', '廣隆', '158', '+2.5', '+1.6', '246', '89']
# company : ['2707', '晶華', '158', '0', '0', '228', '90']
# company : ['8066', '來思達', '157', '-1.5', '-1', '1023', '91']
# company : ['2228', '劍麟', '153', '+0.5', '+0.3', '347', '92']
# company : ['4803', 'VHQ-KY', '153', '+1', '+0.7', '151', '93']
# company : ['3105', '穩懋', '152.5', '+11', '+7.8', '14320', '94']
# company : ['6504', '南六', '151.5', '+5.5', '+3.8', '111', '95']
# company : ['6533', '晶心科', '151', '-2', '-1.3', '535', '96']
# company : ['1536', '和大', '148.5', '-1', '-0.7', '3783', '97']
# company : ['4551', '智伸科', '146', '+3', '+2.1', '279', '98']
# company : ['1256', '鮮活果汁-KY', '144.5', '+1.5', '+1', '92', '99']
# company : ['6446', '藥華藥', '144.5', '0', '0', '166', '100']
# [['3008', '大立光', '4790', '-60', '-1.2', '224', '1'],
#  ['6510', '精測', '1450', '+40', '+2.8', '974', '2'],
#  ['5274', '信驊', '638', '-12', '-1.8', '273', '3'],
#  ['1565', '精華', '595', '+5', '+0.8', '314', '4'],
#  ['6415', '矽力-KY', '580', '-6', '-1', '158', '5'],
#  ['6409', '旭隼', '494', '+3', '+0.6', '133', '6'],
#  ['6452', '康友-KY', '475', '+2.5', '+0.5', '426', '7'],
#  ['2059', '川湖', '444', '+6', '+1.4', '173', '8'],
#  ['5904', '寶雅', '407', '-13', '-3.1', '97', '9'],
#  ['6414', '樺漢', '394.5', '-3.5', '-0.9', '1050', '10'],
#  ['3529', '力旺', '393', '+4', '+1', '91', '11'],
#  ['2207', '和泰車', '386.5', '-3.5', '-0.9', '284', '12'],
#  ['6548', '長華科', '381', '-5', '-1.3', '41', '13'],
#  ['2231', '為升', '368', '+9.5', '+2.6', '1171', '14'],
#  ['4966', '譜瑞-KY', '364', '0', '0', '872', '15'],
#  ['3081', '聯亞', '355', '+7', '+2', '1964', '16'],
#  ['2474', '可成', '354', '+15', '+4.4', '13028', '17'],
#  ['2723', '美食-KY', '345', '+5', '+1.5', '409', '18'],
#  ['8299', '群聯', '341', '-9', '-2.6', '2552', '19'],
#  ['1590', '亞德客-KY', '335.5', '-11.5', '-3.3', '799', '20'],
#  ['3152', '璟德', '332', '-13.5', '-3.9', '592', '21'],
#  ['910708', '恒大健-DR', '332', '0', '0', '0', '22'],
#  ['5269', '祥碩', '330', '-0.5', '-0.2', '1267', '23'],
#  ['1476', '儒鴻', '324', '-1', '-0.3', '435', '24'],
#  ['8464', '億豐', '316.5', '+6', '+1.9', '644', '25'],
#  ['2227', '裕日車', '304', '-2', '-0.6', '485', '26'],
#  ['3406', '玉晶光', '292', '-6', '-2', '3240', '27'],
#  ['2357', '華碩', '289', '-2.5', '-0.9', '806', '28'],
#  ['3691', '碩禾', '286.5', '+0.5', '+0.2', '1042', '29'],
#  ['2912', '統一超', '272', '-3', '-1.1', '838', '30'],
#  ['5287', '數字', '268.5', '-2.5', '-0.9', '106', '31'],
#  ['4174', '浩鼎', '262.5', '-3.5', '-1.3', '367', '32'],
#  ['2729', '瓦城', '258', '0', '0', '21', '33'],
#  ['2496', '卓越', '256', '+10', '+4.1', '497', '34'],
#  ['8044', '網家', '255.5', '+6', '+2.4', '1244', '35'],
#  ['1264', '德麥', '251', '+2', '+0.8', '41', '36'],
#  ['2395', '研華', '249', '+0.5', '+0.2', '263', '37'],
#  ['6569', '醫揚', '248', '+2', '+0.8', '42', '38'],
#  ['6488', '環球晶', '246', '-11', '-4.3', '4206', '39'],
#  ['2454', '聯發科', '245', '+2', '+0.8', '10042', '40'],
#  ['8406', '金可-KY', '244', '-1', '-0.4', '276', '41'],
#  ['6111', '大宇資', '238', '-3.5', '-1.4', '697', '42'],
#  ['3611', '鼎翰', '235.5', '-1.5', '-0.6', '49', '43'],
#  ['6456', 'GIS-KY', '235', '+5', '+2.2', '6287', '44'],
#  ['3665', '貿聯-KY', '227', '-5', '-2.2', '8686', '45'],
#  ['4947', '昂寶-KY', '221.5', '+2', '+0.9', '751', '46'],
#  ['8454', '富邦媒', '217', '+1.5', '+0.7', '182', '47'],
#  ['2727', '王品', '213.5', '-0.5', '-0.2', '588', '48'],
#  ['2330', '台積電', '210.5', '-1.5', '-0.7', '15382', '49'],
#  ['3131', '弘塑', '210', '+5.5', '+2.7', '2062', '50'],
#  ['2049', '上銀', '207', '-3', '-1.4', '1254', '51'],
#  ['6426', '統新', '207', '-5', '-2.4', '1300', '52'],
#  ['3293', '鈊象', '206', '-5', '-2.4', '807', '53'],
#  ['5903', '全家', '206', '+0.5', '+0.2', '4', '54'],
#  ['4162', '智擎', '203', '-1.5', '-0.7', '469', '55'],
#  ['6462', '神盾', '200.5', '+8', '+4.2', '3102', '56'],
#  ['5263', '智崴', '196.5', '-3.5', '-1.8', '195', '57'],
#  ['1707', '葡萄王', '190', '+0.5', '+0.3', '227', '58'],
#  ['9951', '皇田', '189', '-1', '-0.5', '145', '59'],
#  ['4147', '中裕', '186', '-1', '-0.5', '503', '60'],
#  ['3552', '同致', '185.5', '-5.5', '-2.9', '2026', '61'],
#  ['6238', '勝麗', '185', '-1', '-0.5', '607', '62'],
#  ['8422', '可寧衛', '183', '+1.5', '+0.8', '251', '63'],
#  ['2439', '美律', '181.5', '-2.5', '-1.4', '4688', '64'],
#  ['6523', '達爾膚', '179.5', '-3.5', '-1.9', '41', '65'],
#  ['6279', '胡連', '178.5', '-3', '-1.6', '1401', '66'],
#  ['3413', '京鼎', '177.5', '+2.5', '+1.4', '1954', '67'],
#  ['8437', '大地-KY', '177.5', '+0.5', '+0.3', '10', '68'],
#  ['6803', '崑鼎', '176.5', '+1', '+0.6', '27', '69'],
#  ['6568', '宏觀', '176', '+1.5', '+0.9', '216', '70'],
#  ['4763', '材料-KY', '175.5', '0', '0', '191', '71'],
#  ['9921', '巨大', '175.5', '-1.5', '-0.8', '533', '72'],
#  ['8444', '綠河-KY', '175', '+1', '+0.6', '35', '73'],
#  ['8436', '大江', '174.5', '+4.5', '+2.6', '1472', '74'],
#  ['2239', '英利-KY', '174', '+5', '+3', '389', '75'],
#  ['5536', '聖暉', '172.5', '-3', '-1.7', '680', '76'],
#  ['8341', '日友', '170.5', '+4.5', '+2.7', '1072', '77'],
#  ['8114', '振樺電', '169.5', '-1', '-0.6', '85', '78'],
#  ['4912', '聯德控股-KY', '169', '+1', '+0.6', '947', '79'],
#  ['4438', '廣越', '168', '-2.5', '-1.5', '148', '80'],
#  ['1580', '新麥', '167', '-0.5', '-0.3', '93', '81'],
#  ['2308', '台達電', '166', '-3.5', '-2.1', '11608', '82'],
#  ['6146', '耕興', '162.5', '-1.5', '-0.9', '47', '83'],
#  ['2926', '誠品生', '162', '-1', '-0.6', '39', '84'],
#  ['3130', '一零四', '162', '+1', '+0.6', '11', '85'],
#  ['9914', '美利達', '160', '-0.5', '-0.3', '237', '86'],
#  ['8083', '瑞穎', '159.5', '-3', '-1.8', '235', '87'],
#  ['3541', '西柏', '158.5', '0', '0', '58', '88'],
#  ['1537', '廣隆', '158', '+2.5', '+1.6', '246', '89'],
#  ['2707', '晶華', '158', '0', '0', '228', '90'],
#  ['8066', '來思達', '157', '-1.5', '-1', '1023', '91'],
#  ['2228', '劍麟', '153', '+0.5', '+0.3', '347', '92'],
#  ['4803', 'VHQ-KY', '153', '+1', '+0.7', '151', '93'],
#  ['3105', '穩懋', '152.5', '+11', '+7.8', '14320', '94'],
#  ['6504', '南六', '151.5', '+5.5', '+3.8', '111', '95'],
#  ['6533', '晶心科', '151', '-2', '-1.3', '535', '96'],
#  ['1536', '和大', '148.5', '-1', '-0.7', '3783', '97'],
#  ['4551', '智伸科', '146', '+3', '+2.1', '279', '98'],
#  ['1256', '鮮活果汁-KY', '144.5', '+1.5', '+1', '92', '99'],
#  ['6446', '藥華藥', '144.5', '0', '0', '166', '100']]

# %%
def getStcokTransactionTop10():
    main_list = []
    table_list = indicatortable_crawler()
    #取出
    for company in table_list[15].findAll("tr"):
        list_companyInfo = []
        companyInfo = company.findAll("nobr")
        for index in range(0,len(companyInfo)):
            if index>1:
                list_companyInfo.append(companyInfo[index].text[1:])
            else:
                list_companyInfo.append(companyInfo[index].text)
        main_list.append(list_companyInfo)
        print("company : "+str(list_companyInfo))
    return main_list
getStcokTransactionTop10()
# Out:
# company : ['3481', '群創', '14.35', '+0.1', '+0.7', '149361', '1']
# company : ['2409', '友達', '12.25', '+0.25', '+2.1', '108534', '2']
# company : ['2337', '旺宏', '17.95', '+1.15', '+6.8', '102894', '3']
# company : ['2371', '大同', '12.7', '+0.75', '+6.3', '78590', '4']
# company : ['00672L', '元大S&P;原油正2', '13.74', '-0.71', '-4.9', '71534', '5']
# company : ['2344', '華邦電', '18.9', '+0.1', '+0.5', '71194', '6']
# company : ['00637L', '元大滬深300正2', '13.58', '+0.02', '+0.2', '48684', '7']
# company : ['2352', '佳世達', '24.3', '+0.95', '+4.1', '42670', '8']
# company : ['1314', '中石化', '11.7', '+0.35', '+3.1', '41150', '9']
# company : ['6116', '彩晶', '8.17', '+0.08', '+1', '28307', '10']
# company : ['2887', '台新金', '13.7', '0', '0', '28103', '11']
# company : ['2891', '中信金', '19.35', '0', '0', '25456', '12']
# company : ['2881', '富邦金', '45.9', '-0.15', '-0.3', '24860', '13']
# company : ['3037', '欣興', '18.05', '+0.45', '+2.6', '24578', '14']
# company : ['2405', '浩鑫', '9.46', '+0.67', '+7.6', '23811', '15']
# company : ['00642U', '元大S&P;石油', '16.58', '-0.4', '-2.4', '21311', '16']
# company : ['2317', '鴻海', '105', '-0.5', '-0.5', '21309', '17']
# company : ['2449', '京元電子', '30.1', '-0.1', '-0.3', '20941', '18']
# company : ['1909', '榮成', '31.8', '+0.45', '+1.4', '20778', '19']
# company : ['00632R', '元大台灣50反1', '14.45', '0', '0', '19470', '20']
# company : ['6145', '勁永', '14.2', '+0.25', '+1.8', '19341', '21']
# company : ['2401', '凌陽', '14.95', '+0.6', '+4.2', '19216', '22']
# company : ['2886', '兆豐金', '24.7', '+0.1', '+0.4', '18320', '23']
# company : ['00633L', '富邦上証正2', '36.03', '+0.08', '+0.2', '17841', '24']
# company : ['2882', '國泰金', '47.15', '-0.55', '-1.2', '17286', '25']
# company : ['2601', '益航', '9.85', '+0.53', '+5.7', '16871', '26']
# company : ['8358', '金居', '49.1', '+0.45', '+0.9', '16769', '27']
# company : ['2892', '第一金', '19.3', '0', '0', '16569', '28']
# company : ['2311', '日月光', '39.4', '+0.1', '+0.2', '15835', '29']
# company : ['2330', '台積電', '210.5', '-1.5', '-0.7', '15382', '30']
# company : ['2888', '新光金', '7.64', '-0.04', '-0.5', '15176', '31']
# company : ['2884', '玉山金', '18.6', '-0.1', '-0.5', '14972', '32']
# company : ['3105', '穩懋', '152.5', '+11', '+7.8', '14320', '33']
# company : ['2610', '華航', '9.07', '-0.05', '-0.6', '13794', '34']
# company : ['2356', '英業達', '23.65', '+0.05', '+0.2', '13624', '35']
# company : ['2883', '開發金', '8.25', '-0.02', '-0.2', '13181', '36']
# company : ['2474', '可成', '354', '+15', '+4.4', '13028', '37']
# company : ['2890', '永豐金', '9.23', '-0.06', '-0.6', '12111', '38']
# company : ['3374', '精材', '53.1', '+0.9', '+1.7', '11743', '39']
# company : ['2308', '台達電', '166', '-3.5', '-2.1', '11608', '40']
# company : ['2303', '聯電', '12.45', '0', '0', '11596', '41']
# company : ['2885', '元大金', '13.15', '-0.1', '-0.8', '11513', '42']
# company : ['8069', '元太', '30.8', '+0.35', '+1.2', '11141', '43']
# company : ['2880', '華南金', '17.1', '-0.05', '-0.3', '11088', '44']
# company : ['8150', '南茂', '30.6', '-0.45', '-1.4', '11049', '45']
# company : ['2323', '中環', '4.14', '+0.05', '+1.2', '10417', '46']
# company : ['2382', '廣達', '66.6', '-1', '-1.5', '10245', '47']
# company : ['2002', '中鋼', '24.5', '0', '0', '10182', '48']
# company : ['2454', '聯發科', '245', '+2', '+0.8', '10042', '49']
# company : ['3227', '原相', '85.6', '+1.8', '+2.2', '9830', '50']
# company : ['2504', '國產', '10', '+0.23', '+2.4', '9370', '51']
# company : ['5880', '合庫金', '15.8', '+0.05', '+0.3', '9226', '52']
# company : ['2633', '台灣高鐵', '26.1', '0', '0', '8936', '53']
# company : ['2436', '偉詮電', '28.7', '+0.6', '+2.1', '8892', '54']
# company : ['1303', '南亞', '71.7', '+0.2', '+0.3', '8808', '55']
# company : ['3665', '貿聯-KY', '227', '-5', '-2.2', '8686', '56']
# company : ['5328', '華容', '9.94', '+0.56', '+6', '8595', '57']
# company : ['2367', '燿華', '11.45', '+0.2', '+1.8', '8469', '58']
# company : ['4960', '奇美材', '15.35', '+0.15', '+1', '8465', '59']
# company : ['2603', '長榮', '15.05', '-0.05', '-0.3', '8372', '60']
# company : ['2809', '京城銀', '30.15', '+0.3', '+1', '8125', '61']
# company : ['3035', '智原', '39', '+1.4', '+3.7', '8098', '62']
# company : ['2412', '中華電', '108', '0', '0', '7977', '63']
# company : ['2448', '晶電', '31.65', '+0.1', '+0.3', '7908', '64']
# company : ['1216', '統一', '59.5', '0', '0', '7886', '65']
# company : ['2399', '映泰', '12.2', '-0.3', '-2.4', '7878', '66']
# company : ['2314', '台揚', '37.2', '-0.65', '-1.7', '7836', '67']
# company : ['3443', '創意', '113.5', '+10', '+9.7', '7719', '68']
# company : ['2353', '宏碁', '16.45', '+0.05', '+0.3', '7700', '69']
# company : ['2363', '矽統', '7.33', '+0.4', '+5.8', '7689', '70']
# company : ['2313', '華通', '25.05', '-0.15', '-0.6', '7534', '71']
# company : ['1568', '倉佑', '40.7', '+1.45', '+3.7', '7072', '72']
# company : ['2498', '宏達電', '72.8', '+0.8', '+1.1', '6941', '73']
# company : ['2458', '義隆', '45', '-0.1', '-0.2', '6934', '74']
# company : ['8112', '至上', '26.7', '+0.1', '+0.4', '6889', '75']
# company : ['5871', '中租-KY', '77.7', '-1.2', '-1.5', '6831', '76']
# company : ['8086', '宏捷科', '61.7', '+0.1', '+0.2', '6792', '77']
# company : ['5469', '瀚宇博', '17.4', '+0.05', '+0.3', '6710', '78']
# company : ['2402', '毅嘉', '21.4', '-0.45', '-2.1', '6704', '79']
# company : ['3673', 'TPK-KY', '96.2', '+0.6', '+0.6', '6691', '80']
# company : ['2369', '菱生', '15.6', '0', '0', '6690', '81']
# company : ['2301', '光寶科', '50.2', '0', '0', '6647', '82']
# company : ['8215', '明基材', '19.05', '+0.85', '+4.7', '6618', '83']
# company : ['3231', '緯創', '28.7', '0', '0', '6537', '84']
# company : ['00687B', '國泰20年美債', '40.49', '-0.08', '-0.2', '6494', '85']
# company : ['2421', '建準', '35.55', '+0.1', '+0.3', '6490', '86']
# company : ['6456', 'GIS-KY', '235', '+5', '+2.2', '6287', '87']
# company : ['6161', '捷波', '14.6', '-0.5', '-3.3', '6151', '88']
# company : ['2312', '金寶', '11.25', '+0.2', '+1.8', '6118', '89']
# company : ['9904', '寶成', '42.3', '+0.55', '+1.3', '6085', '90']
# company : ['1312', '國喬', '21.05', '+0.2', '+1', '6008', '91']
# company : ['2324', '仁寶', '20.5', '0', '0', '5894', '92']
# company : ['6188', '廣明', '46.9', '-0.2', '-0.4', '5719', '93']
# company : ['3380', '明泰', '26.9', '+0.05', '+0.2', '5719', '94']
# company : ['6274', '台燿', '52', '+1.7', '+3.4', '5709', '95']
# company : ['5305', '敦南', '32', '0', '0', '5695', '96']
# company : ['4991', '環宇-KY', '68.8', '+0.4', '+0.6', '5644', '97']
# company : ['2390', '云辰', '15.3', '+1.35', '+9.7', '5638', '98']
# company : ['2475', '華映', '1.46', '+0.04', '+2.8', '5638', '99']
# company : ['6182', '合晶', '19.5', '-0.2', '-1', '5620', '100']
# [['3481', '群創', '14.35', '+0.1', '+0.7', '149361', '1'],
#  ['2409', '友達', '12.25', '+0.25', '+2.1', '108534', '2'],
#  ['2337', '旺宏', '17.95', '+1.15', '+6.8', '102894', '3'],
#  ['2371', '大同', '12.7', '+0.75', '+6.3', '78590', '4'],
#  ['00672L', '元大S&P;原油正2', '13.74', '-0.71', '-4.9', '71534', '5'],
#  ['2344', '華邦電', '18.9', '+0.1', '+0.5', '71194', '6'],
#  ['00637L', '元大滬深300正2', '13.58', '+0.02', '+0.2', '48684', '7'],
#  ['2352', '佳世達', '24.3', '+0.95', '+4.1', '42670', '8'],
#  ['1314', '中石化', '11.7', '+0.35', '+3.1', '41150', '9'],
#  ['6116', '彩晶', '8.17', '+0.08', '+1', '28307', '10'],
#  ['2887', '台新金', '13.7', '0', '0', '28103', '11'],
#  ['2891', '中信金', '19.35', '0', '0', '25456', '12'],
#  ['2881', '富邦金', '45.9', '-0.15', '-0.3', '24860', '13'],
#  ['3037', '欣興', '18.05', '+0.45', '+2.6', '24578', '14'],
#  ['2405', '浩鑫', '9.46', '+0.67', '+7.6', '23811', '15'],
#  ['00642U', '元大S&P;石油', '16.58', '-0.4', '-2.4', '21311', '16'],
#  ['2317', '鴻海', '105', '-0.5', '-0.5', '21309', '17'],
#  ['2449', '京元電子', '30.1', '-0.1', '-0.3', '20941', '18'],
#  ['1909', '榮成', '31.8', '+0.45', '+1.4', '20778', '19'],
#  ['00632R', '元大台灣50反1', '14.45', '0', '0', '19470', '20'],
#  ['6145', '勁永', '14.2', '+0.25', '+1.8', '19341', '21'],
#  ['2401', '凌陽', '14.95', '+0.6', '+4.2', '19216', '22'],
#  ['2886', '兆豐金', '24.7', '+0.1', '+0.4', '18320', '23'],
#  ['00633L', '富邦上証正2', '36.03', '+0.08', '+0.2', '17841', '24'],
#  ['2882', '國泰金', '47.15', '-0.55', '-1.2', '17286', '25'],
#  ['2601', '益航', '9.85', '+0.53', '+5.7', '16871', '26'],
#  ['8358', '金居', '49.1', '+0.45', '+0.9', '16769', '27'],
#  ['2892', '第一金', '19.3', '0', '0', '16569', '28'],
#  ['2311', '日月光', '39.4', '+0.1', '+0.2', '15835', '29'],
#  ['2330', '台積電', '210.5', '-1.5', '-0.7', '15382', '30'],
#  ['2888', '新光金', '7.64', '-0.04', '-0.5', '15176', '31'],
#  ['2884', '玉山金', '18.6', '-0.1', '-0.5', '14972', '32'],
#  ['3105', '穩懋', '152.5', '+11', '+7.8', '14320', '33'],
#  ['2610', '華航', '9.07', '-0.05', '-0.6', '13794', '34'],
#  ['2356', '英業達', '23.65', '+0.05', '+0.2', '13624', '35'],
#  ['2883', '開發金', '8.25', '-0.02', '-0.2', '13181', '36'],
#  ['2474', '可成', '354', '+15', '+4.4', '13028', '37'],
#  ['2890', '永豐金', '9.23', '-0.06', '-0.6', '12111', '38'],
#  ['3374', '精材', '53.1', '+0.9', '+1.7', '11743', '39'],
#  ['2308', '台達電', '166', '-3.5', '-2.1', '11608', '40'],
#  ['2303', '聯電', '12.45', '0', '0', '11596', '41'],
#  ['2885', '元大金', '13.15', '-0.1', '-0.8', '11513', '42'],
#  ['8069', '元太', '30.8', '+0.35', '+1.2', '11141', '43'],
#  ['2880', '華南金', '17.1', '-0.05', '-0.3', '11088', '44'],
#  ['8150', '南茂', '30.6', '-0.45', '-1.4', '11049', '45'],
#  ['2323', '中環', '4.14', '+0.05', '+1.2', '10417', '46'],
#  ['2382', '廣達', '66.6', '-1', '-1.5', '10245', '47'],
#  ['2002', '中鋼', '24.5', '0', '0', '10182', '48'],
#  ['2454', '聯發科', '245', '+2', '+0.8', '10042', '49'],
#  ['3227', '原相', '85.6', '+1.8', '+2.2', '9830', '50'],
#  ['2504', '國產', '10', '+0.23', '+2.4', '9370', '51'],
#  ['5880', '合庫金', '15.8', '+0.05', '+0.3', '9226', '52'],
#  ['2633', '台灣高鐵', '26.1', '0', '0', '8936', '53'],
#  ['2436', '偉詮電', '28.7', '+0.6', '+2.1', '8892', '54'],
#  ['1303', '南亞', '71.7', '+0.2', '+0.3', '8808', '55'],
#  ['3665', '貿聯-KY', '227', '-5', '-2.2', '8686', '56'],
#  ['5328', '華容', '9.94', '+0.56', '+6', '8595', '57'],
#  ['2367', '燿華', '11.45', '+0.2', '+1.8', '8469', '58'],
#  ['4960', '奇美材', '15.35', '+0.15', '+1', '8465', '59'],
#  ['2603', '長榮', '15.05', '-0.05', '-0.3', '8372', '60'],
#  ['2809', '京城銀', '30.15', '+0.3', '+1', '8125', '61'],
#  ['3035', '智原', '39', '+1.4', '+3.7', '8098', '62'],
#  ['2412', '中華電', '108', '0', '0', '7977', '63'],
#  ['2448', '晶電', '31.65', '+0.1', '+0.3', '7908', '64'],
#  ['1216', '統一', '59.5', '0', '0', '7886', '65'],
#  ['2399', '映泰', '12.2', '-0.3', '-2.4', '7878', '66'],
#  ['2314', '台揚', '37.2', '-0.65', '-1.7', '7836', '67'],
#  ['3443', '創意', '113.5', '+10', '+9.7', '7719', '68'],
#  ['2353', '宏碁', '16.45', '+0.05', '+0.3', '7700', '69'],
#  ['2363', '矽統', '7.33', '+0.4', '+5.8', '7689', '70'],
#  ['2313', '華通', '25.05', '-0.15', '-0.6', '7534', '71'],
#  ['1568', '倉佑', '40.7', '+1.45', '+3.7', '7072', '72'],
#  ['2498', '宏達電', '72.8', '+0.8', '+1.1', '6941', '73'],
#  ['2458', '義隆', '45', '-0.1', '-0.2', '6934', '74'],
#  ['8112', '至上', '26.7', '+0.1', '+0.4', '6889', '75'],
#  ['5871', '中租-KY', '77.7', '-1.2', '-1.5', '6831', '76'],
#  ['8086', '宏捷科', '61.7', '+0.1', '+0.2', '6792', '77'],
#  ['5469', '瀚宇博', '17.4', '+0.05', '+0.3', '6710', '78'],
#  ['2402', '毅嘉', '21.4', '-0.45', '-2.1', '6704', '79'],
#  ['3673', 'TPK-KY', '96.2', '+0.6', '+0.6', '6691', '80'],
#  ['2369', '菱生', '15.6', '0', '0', '6690', '81'],
#  ['2301', '光寶科', '50.2', '0', '0', '6647', '82'],
#  ['8215', '明基材', '19.05', '+0.85', '+4.7', '6618', '83'],
#  ['3231', '緯創', '28.7', '0', '0', '6537', '84'],
#  ['00687B', '國泰20年美債', '40.49', '-0.08', '-0.2', '6494', '85'],
#  ['2421', '建準', '35.55', '+0.1', '+0.3', '6490', '86'],
#  ['6456', 'GIS-KY', '235', '+5', '+2.2', '6287', '87'],
#  ['6161', '捷波', '14.6', '-0.5', '-3.3', '6151', '88'],
#  ['2312', '金寶', '11.25', '+0.2', '+1.8', '6118', '89'],
#  ['9904', '寶成', '42.3', '+0.55', '+1.3', '6085', '90'],
#  ['1312', '國喬', '21.05', '+0.2', '+1', '6008', '91'],
#  ['2324', '仁寶', '20.5', '0', '0', '5894', '92'],
#  ['6188', '廣明', '46.9', '-0.2', '-0.4', '5719', '93'],
#  ['3380', '明泰', '26.9', '+0.05', '+0.2', '5719', '94'],
#  ['6274', '台燿', '52', '+1.7', '+3.4', '5709', '95'],
#  ['5305', '敦南', '32', '0', '0', '5695', '96'],
#  ['4991', '環宇-KY', '68.8', '+0.4', '+0.6', '5644', '97'],
#  ['2390', '云辰', '15.3', '+1.35', '+9.7', '5638', '98'],
#  ['2475', '華映', '1.46', '+0.04', '+2.8', '5638', '99'],
#  ['6182', '合晶', '19.5', '-0.2', '-1', '5620', '100']]
